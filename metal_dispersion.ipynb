# %% [markdown]
# # basic processes of this notebook:
# - read-in simulation data
# - read-in relevant halo catalog (consider 128 & 256 cases)
# - projection plots of the whole domain overplotting 100 most massive halos
# - creating derived fields in notebook environment.
# - zoom-in to the most massive halos, make projection plots of DM, gas, and stellar component
# - calculate gas/star angular momentum vector
# - make projection plots for edge-on and face-on cases
# - generate profiles

# %% [markdown]
# ## python & yt modules

# %%
import yt
import numpy as np
import glob
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams['savefig.dpi'] = 2 * matplotlib.rcParams['savefig.dpi']
plt.style.use('niceplot')

# %%
from yt import derived_field
from yt.units.yt_array import YTQuantity
from yt import YTArray

# %% [markdown]
# ## read in simulation and relevant halo catalog

# %%
data_file = './OUT/continuous_a0.1302.art'
data_ds = yt.load(data_file)
# Out:
# yt : [WARNING  ] 2016-07-25 13:09:16,540 DeltaDC != 0, which implies auni != abox.  Be sure you understand which expansion parameter is appropriate for your use! (Gnedin, Kravtsov, & Rudd 2011)
# yt : [INFO     ] 2016-07-25 13:09:16,597 Parameters: current_time              = 812701920.249 yr
# yt : [INFO     ] 2016-07-25 13:09:16,598 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2016-07-25 13:09:16,600 Parameters: domain_left_edge          = [ 0.  0.  0.]
# yt : [INFO     ] 2016-07-25 13:09:16,602 Parameters: domain_right_edge         = [ 128.  128.  128.]
# yt : [INFO     ] 2016-07-25 13:09:16,604 Parameters: cosmological_simulation   = True
# yt : [INFO     ] 2016-07-25 13:09:16,604 Parameters: current_redshift          = 6.67853282425
# yt : [INFO     ] 2016-07-25 13:09:16,605 Parameters: omega_lambda              = 0.696400016546
# yt : [INFO     ] 2016-07-25 13:09:16,606 Parameters: omega_matter              = 0.303599983454
# yt : [INFO     ] 2016-07-25 13:09:16,607 Parameters: hubble_constant           = 0.681400001049
# {}

# %%
ad = data_ds.all_data()

# %%
mass = ad[("STAR", "initial_mass")].in_units("Msun")
age = ad[("STAR", "age")].in_units("Myr")

star_ctime = data_ds.current_time.in_units('Myr')-age
# Out:
# yt : [INFO     ] 2016-07-25 13:09:35,886 Loading field plugins.
# yt : [INFO     ] 2016-07-25 13:09:35,887 Loaded angular_momentum (8 new fields)
# yt : [INFO     ] 2016-07-25 13:09:35,887 Loaded astro (15 new fields)
# yt : [INFO     ] 2016-07-25 13:09:35,888 Loaded cosmology (22 new fields)
# yt : [INFO     ] 2016-07-25 13:09:35,889 Loaded fluid (63 new fields)
# yt : [INFO     ] 2016-07-25 13:09:35,890 Loaded fluid_vector (95 new fields)
# yt : [INFO     ] 2016-07-25 13:09:35,891 Loaded geometric (111 new fields)
# yt : [INFO     ] 2016-07-25 13:09:35,892 Loaded local (111 new fields)
# yt : [INFO     ] 2016-07-25 13:09:35,892 Loaded magnetic_field (119 new fields)
# yt : [INFO     ] 2016-07-25 13:09:35,893 Loaded my_plugins (119 new fields)
# yt : [INFO     ] 2016-07-25 13:09:35,894 Loaded species (121 new fields)
# yt : [INFO     ] 2016-07-25 13:09:40,294 Created 2048 chunks for ARTIO

# %%
data_ds.field_list
# Out:
# [('artio', 'HVAR_GAS_DENSITY'),
#  ('artio', 'HVAR_GAS_ENERGY'),
#  ('artio', 'HVAR_PRESSURE'),
#  ('artio', 'HVAR_GAMMA'),
#  ('artio', 'HVAR_INTERNAL_ENERGY'),
#  ('artio', 'HVAR_MOMENTUM_X'),
#  ('artio', 'HVAR_MOMENTUM_Y'),
#  ('artio', 'HVAR_MOMENTUM_Z'),
#  ('artio', 'RT_HVAR_HI'),
#  ('artio', 'RT_HVAR_HII'),
#  ('artio', 'RT_HVAR_HeI'),
#  ('artio', 'RT_HVAR_HeII'),
#  ('artio', 'RT_HVAR_HeIII'),
#  ('artio', 'RT_HVAR_H2'),
#  ('artio', 'HVAR_METAL_DENSITY_II'),
#  ('artio', 'HVAR_METAL_DENSITY_Ia'),
#  ('artio', 'HVAR_GAS_TURBULENT_ENERGY'),
#  ('artio', 'HVAR_SGST_MEAN_VELOCITY_X'),
#  ('artio', 'HVAR_SGST_MEAN_VELOCITY_Y'),
#  ('artio', 'HVAR_SGST_MEAN_VELOCITY_Z'),
#  ('artio', 'VAR_POTENTIAL'),
#  ('artio', 'VAR_POTENTIAL_HYDRO'),
#  ('artio', 'RT_DISK_VAR_0'),
#  ('artio', 'RT_DISK_VAR_1'),
#  ('artio', 'RT_DISK_VAR_2'),
#  ('artio', 'RT_DISK_VAR_3'),
#  ('artio', 'RT_DISK_VAR_4'),
#  ('artio', 'RT_DISK_VAR_5'),
#  ('artio', 'RT_DISK_VAR_6'),
#  ('artio', 'RT_DISK_VAR_7'),
#  ('STAR', 'AVERAGE_LEVEL'),
#  ('N-BODY', 'POSITION_Y'),
#  ('STAR', 'BIRTH_TIME'),
#  ('N-BODY', 'POSITION_Z'),
#  ('N-BODY', 'PID'),
#  ('N-BODY', 'VELOCITY_Y'),
#  ('STAR', 'BOUND_FRACTION'),
#  ('STAR', 'TIMESTEP'),
#  ('N-BODY', 'TIMESTEP'),
#  ('N-BODY', 'SPECIES'),
#  ('STAR', 'METALLICITY_SNIa'),
#  ('STAR', 'INITIAL_MASS'),
#  ('N-BODY', 'POSITION_X'),
#  ('STAR', 'VELOCITY_X'),
#  ('N-BODY', 'VELOCITY_X'),
#  ('STAR', 'MASS'),
#  ('STAR', 'POSITION_X'),
#  ('STAR', 'SPECIES'),
#  ('N-BODY', 'MASS'),
#  ('STAR', 'AVERAGE_AGE'),
#  ('STAR', 'VELOCITY_Y'),
#  ('STAR', 'POSITION_Z'),
#  ('STAR', 'POSITION_Y'),
#  ('N-BODY', 'VELOCITY_Z'),
#  ('STAR', 'PID'),
#  ('STAR', 'METALLICITY_SNII'),
#  ('STAR', 'VELOCITY_Z'),
#  ('STAR', 'TERMINATION_TIME'),
#  ('all', 'VELOCITY_X'),
#  ('all', 'TIMESTEP'),
#  ('all', 'POSITION_Y'),
#  ('all', 'PID'),
#  ('all', 'MASS'),
#  ('all', 'POSITION_X'),
#  ('all', 'VELOCITY_Y'),
#  ('all', 'POSITION_Z'),
#  ('all', 'SPECIES'),
#  ('all', 'VELOCITY_Z')]

# %%
ZZ = ad[('STAR', 'AVERAGE_LEVEL')]
Z = ad[('STAR', 'METALLICITY_SNII')]

# %%
d = ZZ/mass.in_units('code_mass').value - Z*Z

# %%
std = np.sqrt(d[d>0])

# %%
plt.hist(std)
# Out:
# (array([  2.45200000e+03,   2.91300000e+03,   1.79300000e+03,
#           8.86000000e+02,   3.74000000e+02,   1.53000000e+02,
#           4.00000000e+01,   2.60000000e+01,   3.00000000e+00,
#           2.00000000e+00]),
#  array([  8.12602074e-10,   4.79919036e-04,   9.59837258e-04,
#           1.43975548e-03,   1.91967370e-03,   2.39959193e-03,
#           2.87951015e-03,   3.35942837e-03,   3.83934660e-03,
#           4.31926482e-03,   4.79918304e-03]),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(Z[d>0], std, s=2)
plt.xlim(1e-4,0.015)
plt.ylim(1e-5,5e-3)
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'$M_Z/M$')
plt.ylabel(r'$\sigma_Z$')

# %%
plt.scatter(mass[d>0], std, s=2)
plt.xlim(1e3,1e5)
plt.ylim(1e-5,5e-3)
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'$M \; (M_\odot)$')
plt.ylabel(r'$\sigma_Z$')
